# %%
import pandas as pd
import numpy as np

# %%
## pandas is for structure and unstructured data
##bcreate a dummy data
id=np.arange(1,51)
column=["ca1","ca2","ca3"]
np.random.seed(1)
score=np.random.randint(1,11,150)
score=score.reshape(50,3)
df=pd.DataFrame(data=score,index=id,columns=column)
df
# Out:
#     ca1  ca2  ca3
# 1     6    9   10
# 2     6    1    1
# 3     2    8    7
# 4    10    3    5
# 5     6    3    5
# 6     3    5    8
# 7     8   10    2
# 8     8    1    7
# 9    10   10    8
# 10    7   10    2
# 11    1    2    9
# 12    9    4   10
# 13    9    8    4
# 14    7    6    2
# 15   10    4    5
# 16    9    2    5
# 17    1    4   10
# 18    3    1    5
# 19   10    3    8
# 20    8   10    9
# 21    7   10    4
# 22    8    8    5
# 23    6   10    4
# 24    7    9    1
# 25    3    8    8
# 26   10    8    4
# 27    1    9    8
# 28    8    2    2
# 29    4    1    9
# 30    7    5    6
# 31    7    3    6
# 32    8    9    5
# 33    5    8    8
# 34    5   10    1
# 35    3    1    8
# 36    2    8   10
# 37    9    5    1
# 38    2   10    9
# 39    3    4    2
# 40    3    8    3
# 41    7    1   10
# 42    3    7    7
# 43    3    8    8
# 44    1    7    6
# 45    2    5    7
# 46    1    7    6
# 47    2    3    2
# 48    6    5    1
# 49    8    9   10
# ...

# %%
df
# Out:
#     ca1  ca2  ca3
# 1     6    9   10
# 2     6    1    1
# 3     2    8    7
# 4    10    3    5
# 5     6    3    5
# 6     3    5    8
# 7     8   10    2
# 8     8    1    7
# 9    10   10    8
# 10    7   10    2
# 11    1    2    9
# 12    9    4   10
# 13    9    8    4
# 14    7    6    2
# 15   10    4    5
# 16    9    2    5
# 17    1    4   10
# 18    3    1    5
# 19   10    3    8
# 20    8   10    9
# 21    7   10    4
# 22    8    8    5
# 23    6   10    4
# 24    7    9    1
# 25    3    8    8
# 26   10    8    4
# 27    1    9    8
# 28    8    2    2
# 29    4    1    9
# 30    7    5    6
# 31    7    3    6
# 32    8    9    5
# 33    5    8    8
# 34    5   10    1
# 35    3    1    8
# 36    2    8   10
# 37    9    5    1
# 38    2   10    9
# 39    3    4    2
# 40    3    8    3
# 41    7    1   10
# 42    3    7    7
# 43    3    8    8
# 44    1    7    6
# 45    2    5    7
# 46    1    7    6
# 47    2    3    2
# 48    6    5    1
# 49    8    9   10
# ...

# %%
df[["ca1"]].head()
# Out:
#    ca1
# 1    6
# 2    6
# 3    2
# 4   10
# 5    6

# %%
## selecting multiple columns
df[["ca1","ca2"]].head()
# Out:
#    ca1  ca2
# 1    6    9
# 2    6    1
# 3    2    8
# 4   10    3
# 5    6    3

# %%
## it shows data value for index 5 for all the column
df.loc[5]
# Out:
# ca1    6
# ca2    3
# ca3    5
# Name: 5, dtype: int32

# %%
## it shows the data value for the next index (6) after the mention index 5
df.iloc[5] # df.iloc[5] = df.loc[6]
# Out:
# ca1    3
# ca2    5
# ca3    8
# Name: 6, dtype: int32

# %%
## selecting multiple row in dataframe
df.loc[[20,21,24,25,26,19]]
# Out:
#     ca1  ca2  ca3
# 20    8   10    9
# 21    7   10    4
# 24    7    9    1
# 25    3    8    8
# 26   10    8    4
# 19   10    3    8

# %%
df.iloc[[20,21,24,25,26,19]]
# Out:
#     ca1  ca2  ca3
# 21    7   10    4
# 22    8    8    5
# 25    3    8    8
# 26   10    8    4
# 27    1    9    8
# 20    8   10    9

# %%
np.random.seed(1)
age=np.random.randint(11,16,50).reshape(50,1)
df.insert(loc=3,value=age,column="Age")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 np.random.seed(1)
#       2 age=np.random.randint(11,16,50).reshape(50,1)
#       3 df.insert(loc=3,value=age,column="Age")
#
# NameError: name 'np' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
np.random.seed(1)
exam=np.random.randint(20,90,50).reshape(50,1)
df.insert(loc=5,value=exam,column="Exam2")
df.head()
# Out:
#    ca1  ca2  ca3  Exam  Age  Exam2
# 1    6    9   10    57   14     57
# 2    6    1    1    32   15     32
# 3    2    8    7    92   11     29
# 4   10    3    5    29   12     25
# 5    6    3    5    95   14     84

# %%
np.random.seed(1)
df["exam"]=np.random.randint(20,90,50).reshape(50,1)
df.head()
# Out:
#    ca1  ca2  ca3  Exam  Age  Exam2  exam
# 1    6    9   10    57   14     57    57
# 2    6    1    1    32   15     32    32
# 3    2    8    7    92   11     29    29
# 4   10    3    5    29   12     25    25
# 5    6    3    5    95   14     84    84

# %%
df["Totalscore"]=df["ca1"]+df["ca2"]+df["ca3"]+df["Age"]+df["exam"]
df.head()
# Out:
#    ca1  ca2  ca3  Exam  Age  Exam2  exam  Totalscore
# 1    6    9   10    57   14     57    57          96
# 2    6    1    1    32   15     32    32          55
# 3    2    8    7    92   11     29    29          57
# 4   10    3    5    29   12     25    25          55
# 5    6    3    5    95   14     84    84         112

# %%
df["AverageScore"]=df["ca1"]+df["ca2"]+df["ca3"]+df["Age"]+df["exam"]/5
df.head()
# Out:
#    ca1  ca2  ca3  Exam  Age  Exam2  exam  Totalscore  AverageScore
# 1    6    9   10    57   14     57    57          96          50.4
# 2    6    1    1    32   15     32    32          55          29.4
# 3    2    8    7    92   11     29    29          57          33.8
# 4   10    3    5    29   12     25    25          55          35.0
# 5    6    3    5    95   14     84    84         112          44.8

# %%
df.columns
# Out:
# Index(['ca1', 'ca2', 'ca3', 'Exam', 'Age', 'Exam2', 'exam', 'Totalscore',
#        'AverageScore'],
#       dtype='object')

# %%
df.loc[[1,3,7]]
# Out:
#    ca1  ca2  ca3  Age
# 1    6    9   10   14
# 3    2    8    7   11
# 7    8   10    2   11

# %%
for x in df.columns:(
    print(df[x].nunique()))
# Out:
# 10
# 10
# 10
# 40
# 5
# 37
# 37
# 37
# 43

# %%
for x in df.columns:(
    print(df[x].unique()))
# Out:
# [ 6  2 10  3  8  7  1  9  4  5]
# [ 9  1  8  3  5 10  2  4  6  7]
# [10  1  7  5  8  2  9  4  6  3]
# [57 32 92 29 95 25 99 84 36 21 96 91 26 45 70 40 38 31 48 49 34 88 33 27
#  83 81 42 77 20 80 28 67 50 23 90 41 69 44 63 46]
# [14 15 11 12 13]
# [57 32 29 25 84 36 21 26 45 70 40 38 31 48 49 34 88 33 27 83 81 42 77 20
#  80 28 67 50 23 41 69 44 63 46 72 61 35]
# [57 32 29 25 84 36 21 26 45 70 40 38 31 48 49 34 88 33 27 83 81 42 77 20
#  80 28 67 50 23 41 69 44 63 46 72 61 35]
# [ 96  55  57 112  63  52  54  88 104  64  74  67  76  83 100 110  69 116
#  113  70 108  50  53  66  95  71  94 109  49 123  65  89  78  91  61 117
#   84]
# [50.4 29.4 33.8 35.  44.8 34.2 35.2 33.2 52.  48.  32.  43.6 42.2 37.6
#  43.8 36.8 44.  39.6 42.6 45.8 41.4 49.6 48.2 36.4 46.4 38.2 34.  40.
#  30.6 43.  36.6 38.8 47.4 52.6 29.8 38.6 41.2 33.  46.6 29.  32.4 47.2
#  38. ]

# %%
for x in df.columns:(
    print(df[x].value_counts()))
# Out:
# ca1
# 3     8
# 8     7
# 7     7
# 6     6
# 2     5
# 10    5
# 1     5
# 9     4
# 5     2
# 4     1
# Name: count, dtype: int64
# ca2
# 8     10
# 10     8
# 1      6
# 9      5
# 3      5
# 5      5
# 4      4
# 2      3
# 7      3
# 6      1
# Name: count, dtype: int64
# ca3
# 8     8
# 5     7
# 10    6
# 1     6
# 2     6
# 7     4
# 9     4
# 4     4
# 6     4
# 3     1
# Name: count, dtype: int64
# Exam
# 23    2
# 92    2
# 29    2
# 33    2
# 88    2
# 77    2
# 21    2
# 96    2
# 91    2
# 70    2
# 67    1
# 42    1
# 20    1
# 80    1
# 28    1
# 57    1
# 50    1
# 83    1
# 90    1
# 41    1
# 69    1
# 44    1
# 63    1
# 81    1
# 34    1
# 27    1
# 32    1
# 49    1
# 48    1
# 31    1
# 38    1
# 40    1
# 45    1
# 26    1
# 36    1
# 84    1
# 99    1
# 25    1
# 95    1
# 46    1
# Name: count, dtype: int64
# Age
# 12    14
# 15    12
# 11    10
# 14     8
# 13     6
# Name: count, dtype: int64
# Exam2
# 45    3
# 88    3
# 27    2
# 29    2
# 84    2
# ...

# %%
## renaming a column
df.rename({"Totalscore":"Total"},axis=1,inplace=True)
df
# Out:
#     ca1  ca2  ca3  Exam  Age  Exam2  exam  Total  AverageScore
# 1     6    9   10    57   14     57    57     96          50.4
# 2     6    1    1    32   15     32    32     55          29.4
# 3     2    8    7    92   11     29    29     57          33.8
# 4    10    3    5    29   12     25    25     55          35.0
# 5     6    3    5    95   14     84    84    112          44.8
# 6     3    5    8    25   11     36    36     63          34.2
# 7     8   10    2    99   11     21    21     52          35.2
# 8     8    1    7    84   12     26    26     54          33.2
# 9    10   10    8    36   15     45    45     88          52.0
# 10    7   10    2    21   15     70    70    104          48.0
# 11    1    2    9    96   12     40    40     64          32.0
# 12    9    4   10    91   13     38    38     74          43.6
# 13    9    8    4    26   15     31    31     67          42.2
# 14    7    6    2    45   13     48    48     76          37.6
# ...

# %%
total_score=df['Exam'].sum()
df.loc['Total']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 total_score=df['Exam'].sum()
#       2 df.loc['Total']
#
# NameError: name 'df' is not defined

# %%
df.drop(columns=["Exam2"],axis=1,inplace=True)
df
# Out:
#     ca1  ca2  ca3  Exam  Age  exam  Total  AverageScore
# 1     6    9   10    57   14    57     96          50.4
# 2     6    1    1    32   15    32     55          29.4
# 3     2    8    7    92   11    29     57          33.8
# 4    10    3    5    29   12    25     55          35.0
# 5     6    3    5    95   14    84    112          44.8
# 6     3    5    8    25   11    36     63          34.2
# 7     8   10    2    99   11    21     52          35.2
# 8     8    1    7    84   12    26     54          33.2
# 9    10   10    8    36   15    45     88          52.0
# 10    7   10    2    21   15    70    104          48.0
# 11    1    2    9    96   12    40     64          32.0
# 12    9    4   10    91   13    38     74          43.6
# 13    9    8    4    26   15    31     67          42.2
# 14    7    6    2    45   13    48     76          37.6
# 15   10    4    5    70   15    49     83          43.8
# 16    9    2    5    40   14    34     64          36.8
# ...

# %%
## df.drop(columns=["Exam2"],axis=1,inplace=True)

# %%
## drop a row
df.drop(49,axis=0,inplace=True)
df.head()
# Out:
#    ca1  ca2  ca3  Exam  Age  exam  Total  AverageScore
# 1    6    9   10    57   14    57     96          50.4
# 2    6    1    1    32   15    32     55          29.4
# 3    2    8    7    92   11    29     57          33.8
# 4   10    3    5    29   12    25     55          35.0
# 5    6    3    5    95   14    84    112          44.8

# %%
df=pd.DataFrame({
    "Players":["Williams","Giannis","Lebron James","Steph curry","Jordan"],
    "performance":[90,80,86,90,85]
})
df.head()
# Out:
#         Players  performance
# 0      Williams           90
# 1       Giannis           80
# 2  Lebron James           86
# 3   Steph curry           90
# 4        Jordan           85
