# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_excel("File_Complete-Sample-Movement - Anambra - June 2022.xlsx")
df.head(3)
# Out:
#   SAMPLE ID  SHIPMENT #       STAGE TEST TYPE TEMPERATURE           FUNDER  \
# 0  V/034/22  AHL-168167  Dispatched       EID          26  The Global Fund
# 1  V/033/22  AHL-168167  Dispatched       EID          26  The Global Fund
# 2  V/029/22  AHL-168167  Dispatched       EID          26  The Global Fund
#
#         IP    STATE     LGA FACILITY CODE  ... PICKUP DATE  PICKUP TIME  \
# 0  FHI 360  ANAMBRA  Ihiala      ANB33/02  ...  10/06/2022  09:25:00 AM
# 1  FHI 360  ANAMBRA  Ihiala      ANB33/02  ...  10/06/2022  09:25:00 AM
# 2  FHI 360  ANAMBRA  Ihiala      ANB33/02  ...  10/06/2022  09:25:00 AM
#
#                     3PL                  RIDER LAB STATE      LAB LGA  \
# 0  AVO Health Logistics  MarkAthony (AHL-0327)   ANAMBRA  Nnewi North
# 1  AVO Health Logistics  MarkAthony (AHL-0327)   ANAMBRA  Nnewi North
# 2  AVO Health Logistics  MarkAthony (AHL-0327)   ANAMBRA  Nnewi North
#
#    LAB CODE                                           LAB NAME  \
# ...

# %%
df.isnull().sum()
# Out:
# SAMPLE ID             2
# SHIPMENT #            0
# STAGE                 0
# TEST TYPE             0
# TEMPERATURE           0
# FUNDER               35
# IP                    0
# STATE                 0
# LGA                   0
# FACILITY CODE         0
# FACILITY NAME         0
# PICKUP DATE           0
# PICKUP TIME           0
# 3PL                   0
# RIDER                 0
# LAB STATE             0
# LAB LGA               0
# LAB CODE              0
# LAB NAME              0
# LAB RECEIVED DATE     0
# LAB RECEIVED TIME     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# SAMPLE ID            0
# SHIPMENT #           0
# STAGE                0
# TEST TYPE            0
# TEMPERATURE          0
# FUNDER               0
# IP                   0
# STATE                0
# LGA                  0
# FACILITY CODE        0
# FACILITY NAME        0
# PICKUP DATE          0
# PICKUP TIME          0
# 3PL                  0
# RIDER                0
# LAB STATE            0
# LAB LGA              0
# LAB CODE             0
# LAB NAME             0
# LAB RECEIVED DATE    0
# LAB RECEIVED TIME    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['SAMPLE ID', 'SHIPMENT #', 'STAGE', 'TEST TYPE', 'TEMPERATURE',
#        'FUNDER', 'IP', 'STATE', 'LGA', 'FACILITY CODE', 'FACILITY NAME',
#        'PICKUP DATE', 'PICKUP TIME', '3PL', 'RIDER', 'LAB STATE', 'LAB LGA',
#        'LAB CODE', 'LAB NAME', 'LAB RECEIVED DATE', 'LAB RECEIVED TIME'],
#       dtype='object')

# %%
fig=px.histogram(df,x="TEST TYPE",text_auto=True,marginal="violin")
fig.show()

# %%
fig=px.bar(df,x="TEMPERATURE",y="TEST TYPE",text_auto=True,color="TEST TYPE")
fig.show()
