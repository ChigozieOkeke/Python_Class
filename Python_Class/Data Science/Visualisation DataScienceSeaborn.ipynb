# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("File_tips.csv")
df
# Out:
#      Total_bill   Tip     Sex Smoker   Day    Time  Size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.style.use("ggplot")
sns.displot(x=df["Total_bill"],kde=True)
#This code sets the style of the plot to "ggplot" 
# and creates a histogram of the "Total_bill" column
# of the dataframe df with a kernel density estimate (kde) curve.
# The histogram shows the distribution of the total bill amounts 
# in the dataset.
# The kde curve is a smoothed estimate of the probability density function,
# which can help identify the underlying distribution of the data.

# %%
sns.regplot(x=df["Total_bill"],y=df["Tip"])
# Out:
# <Axes: xlabel='Total_bill', ylabel='Tip'>

# %%
sns.regplot(x=df["Total_bill"],y=df["Size"])
# Out:
# <Axes: xlabel='Total_bill', ylabel='Size'>

# %%
sns.scatterplot(x=df["Total_bill"],y=df["Tip"],palette='colorblind',hue=df["Day"])
# Out:
# <Axes: xlabel='Total_bill', ylabel='Tip'>

# %%
sns.scatterplot(x=df["Total_bill"],y=df["Size"])
# Out:
# <Axes: xlabel='Total_bill', ylabel='Size'>

# %%
sns.countplot(x=df["Day"],color="blue")
# Out:
# <Axes: xlabel='Day', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
ln=sns.barplot(x="Sex",y="Total_bill",data=df,palette="Purples",hue="Day")

# %%
## 
plt.figure(figsize=(10,5))
ln=sns.barplot(x="Sex",y="Total_bill",data=df,palette="Greens",estimator="max",hue="Day")

for p in ln.patches:
    ln.annotate(f"{p.get_height()}",(p.get_x()  + p.get_width()/2.,p.get_height()),
                ha="center",va="baseline",fontsize=10,color="black",xytext=(0,5),
                textcoords="offset points")
    
plt.title("Day Distribution")
plt.xticks(rotation=45)
plt.legend(loc=[1,0])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x="Sex",y="Total_bill",data=df,palette="Greens",hue="Day")
# Out:
# <Axes: xlabel='Sex', ylabel='Total_bill'>

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x="Sex",y="Total_bill",data=df,palette=["gold","purple","brown","green"],hue="Day")
# Out:
# <Axes: xlabel='Sex', ylabel='Total_bill'>

# %%
plt.figure(figsize=(10,5))
sns.swarmplot(x="Sex",y="Total_bill",data=df,palette="Purples",hue="Day")
# Out:
# <Axes: xlabel='Sex', ylabel='Total_bill'>

# %%
plt.figure(figsize=(10,5))
sns.swarmplot(x="Sex",y="Total_bill",data=df,palette=["green","blue","purple","pink"],hue="Day")
# Out:
# <Axes: xlabel='Sex', ylabel='Total_bill'>

# %%
sns.boxplot(y=df["Total_bill"],x=df["Day"],palette='colorblind')
# Out:
# C:\Users\hdwipe\AppData\Local\Temp\ipykernel_12448\3427707679.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=df["Total_bill"],x=df["Day"],palette='colorblind')
# <Axes: xlabel='Day', ylabel='Total_bill'>

# %%
sns.boxplot(y=df["Total_bill"],x=df["Day"],palette=["gold","green"],hue=df["Sex"])
plt.xlabel("Day of the Week")
plt.ylabel("Total Bill")
plt.title("Box Plot of Total Bill by Day of the Week and Sex")
# Out:
# Text(0.5, 1.0, 'Box Plot of Total Bill by Day of the Week and Sex')

# %%
sns.barplot(y=df["Total_bill"],x=df["Day"],hue=df["Sex"],palette=["gold","green"])
plt.title("BARPLOT OF TOTAL BILL AGAINST DAY AND SEX")
plt.ylabel("TOTAL BILL")
plt.xlabel("DAY OF THE WEEK")
plt.legend(loc=[1,1])

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(12,10))
ax=sns.barplot(x=df["Sex"],y=df["Total_bill"],data=df,palette="Greens",estimator=max)
   
for p in ln.patches:
    ax.annotate(f"{p.get_height()}",(p.get_x()  + p.get_width()/2.,p.get_height()),
                ha="center",va="baseline",fontsize=10,color="black",xytext=(0,5),
                textcoords="offset points")
plt.title("DAY DISTRIBUTION")
plt.xticks(rotation=45)
plt.legend(loc=[1,0])
plt.show()
#
#palet
# Out:
# C:\Users\hdwipe\AppData\Local\Temp\ipykernel_12448\2361797638.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(x=df["Sex"],y=df["Total_bill"],data=df,palette="Greens",estimator=max)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(12,10))
ax=sns.barplot(x=df["Sex"],y=df["Total_bill"],data=df,hue="Day",palette=["gold","blue","green","purple"],estimator=max)
   # Anotation
for p in ax.patches:
    ax.annotate(f"{p.get_height()}",(p.get_x()  + p.get_width()/2.,p.get_height()),
                ha="center",va="baseline",fontsize=10,color="black",xytext=(0,5),
                textcoords="offset points")
plt.title("DAY DISTRIBUTION")
plt.xticks(rotation=45)
plt.legend(loc="best")
plt.show()

# %%
# palette colors
#deep
#bright
#dark
#plasma
#inferno
#vlag
#colorblind
#pastel
#rocket
#coolwarm
# viridis

# %%
df2=df[["Total_bill","Tip","Size"]]
corr=df2.corr()
corr
# Out:
#             Total_bill       Tip      Size
# Total_bill    1.000000  0.675734  0.598315
# Tip           0.675734  1.000000  0.489299
# Size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,fmt="0.2g")
# Out:
# <Axes: >

# %%
# Assignment
# SHOW THE DISTRIBUTION BETWEEN THE TIP OF A PARTICULAR DAY
# SHOW THE TREND OR THE RELATIONSHIP BETWEEN THE TIPS AND TOTAL_BILL.
# Life expectancy of another country

# %%
df3=df[["Tip","Total_bill"]]
corr=df3.corr()
corr
# Out:
#                  Tip  Total_bill
# Tip         1.000000    0.675734
# Total_bill  0.675734    1.000000

# %%
sns.heatmap(corr,annot=True,fmt="0.2g")
# Out:
# <Axes: >
